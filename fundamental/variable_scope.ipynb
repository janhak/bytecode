# %% [markdown]
# # Understanding variable scope
#
# Please consider the following function:
# ```
# def f1(a):
#     print(a)
#     print(b)
# ```
# if you call it like so: `f1(3)` you probobly woudn't be suprised to see a `NameError: name 'b' is not defined`. Let's fix it:

# %%
b = 6

def f1(a):
    print(a)
    print(b)
    
f1(3)

# %% [markdown]
# Now it should run fine, How about `f2` below should it also succeed?

# %%
def f2(a):
    print(a)
    print(b)
    b = 9
    
f2(3)

# %% [markdown]
# Were you correct in your assumptions? If so can you explain why?

# %%
import dis
