# %% [markdown]
# # Why does the code inside the function runs faster?
#
# Consider the following files:
# #### outside_fn.py
# ```
# for i in range(10**8):
#     i
# ```
# #### inside_fn.py
# ```
# def run_loop():
#     for i in range(10**8):
#         i
#
# run_loop()
# ```
#
# Timing the execution of both return the following figures:
# ```
# > time python outside_fn.py
# python outside_fn.py 4.97s
#
# > time python inside_fn.py
# python inside_fn.py 2.22s
# ```
# That is quite a difference for the same work done. Can you explain?

# %%
outside = """
for i in range(10**8):
    i
"""

def run_loop():
    for i in range(10**8):
        i

# %%
import dis
