# %% [markdown]
# # Tuple += assignment puzzle
#
# Try to think through what would happen when evaluating the expressions below and choose the best answer:

# %%
t = (1, 2, [30, 40])
t[2] += [50, 60]

# %% [markdown]
# 1. `t` becomes `(1, 2, [30, 40, 50, 60])`
# 2. `TypeError` is raised with message `'tuple' object does not support item assingment`.
# 3. Neither.
# 4. Both **1.** and **2.**
#
# If you are confident that you know the right answer run the example above and verify. Where you correct in your assumptions? If so can you explain why. If not what caused the suprise. (as always answer is in the bytecode!)
